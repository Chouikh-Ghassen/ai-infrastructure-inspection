# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# %%
# %cd yolov5

# %%
# !wget https://github.com/Chouikh-Ghassen/ai-infrastructure-inspection/raw/main/models/best.pt

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !python detect.py --weights best.pt --source your_image_name(.png.jpg) --img 640 --conf 0.25

# %%
from IPython.display import Image
Image("runs/detect/exp/your_image_name(.png.jpg)")
